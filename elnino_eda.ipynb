# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
import os

# %%
# !ls
# Out:
# elnino.csv       elnino_eda.ipynb

# %%
os.path.abspath("elnino.csv")
# Out:
# '/Users/astrid_cyj/kaggle/elnino/elnino.csv'

# %%
df = pd.read_csv('/Users/astrid_cyj/kaggle/elnino/elnino.csv')
df.columns = [col.strip() for col in df.columns]
df.columns = [col.replace(' ','_') for col in df.columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178080 entries, 0 to 178079
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Observation       178080 non-null  int64
#  1   Year              178080 non-null  int64
#  2   Month             178080 non-null  int64
#  3   Day               178080 non-null  int64
#  4   Date              178080 non-null  int64
#  5   Latitude          178080 non-null  float64
#  6   Longitude         178080 non-null  float64
#  7   Zonal_Winds       178080 non-null  object
#  8   Meridional_Winds  178080 non-null  object
#  9   Humidity          178080 non-null  object
#  10  Air_Temp          178080 non-null  object
#  11  Sea_Surface_Temp  178080 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 16.3+ MB

# %%
df.head()
# Out:
#    Observation  Year  Month  Day    Date  Latitude  Longitude Zonal_Winds  \
# 0            1    80      3    7  800307     -0.02    -109.46        -6.8
# 1            2    80      3    8  800308     -0.02    -109.46        -4.9
# 2            3    80      3    9  800309     -0.02    -109.46        -4.5
# 3            4    80      3   10  800310     -0.02    -109.46        -3.8
# 4            5    80      3   11  800311     -0.02    -109.46        -4.2
#
#   Meridional_Winds Humidity Air_Temp Sea_Surface_Temp
# 0              0.7        .    26.14            26.24
# 1              1.1        .    25.66            25.97
# 2              2.2        .    25.69            25.28
# 3              1.9        .    25.57            24.31
# 4              1.5        .     25.3            23.19

# %%
df.tail()
# Out:
#         Observation  Year  Month  Day    Date  Latitude  Longitude  \
# 178075       178076    98      6   11  980611      8.96    -140.33
# 178076       178077    98      6   12  980612      8.96    -140.32
# 178077       178078    98      6   13  980613      8.95    -140.34
# 178078       178079    98      6   14  980614      8.96    -140.33
# 178079       178080    98      6   15  980615      8.95    -140.33
#
#        Zonal_Winds Meridional_Winds Humidity Air_Temp Sea_Surface_Temp
# 178075        -5.1             -0.4     94.1    26.04            28.14
# 178076        -4.3             -3.3     93.2     25.8            27.87
# 178077        -6.1             -4.8     81.3    27.17            27.93
# 178078        -4.9             -2.3     76.2    27.36            28.03
# 178079           .                .        .    27.09            28.09

# %%
df['Year'].value_counts()
# Out:
# 97    22238
# 95    21947
# 96    21825
# 94    21351
# 93    20609
# 92    16011
# 98    10076
# 91     8800
# 90     8437
# 89     7929
# 88     6136
# 87     4688
# 86     3780
# 85     1684
# 84      947
# 81      545
# 82      505
# 83      406
# 80      166
# Name: Year, dtype: int64

# %% [markdown]
# ## Choose year 97 as a plot example

# %%
g = sns.lineplot(data=df, x="Year", y="Air_Temp", hue="Month")
